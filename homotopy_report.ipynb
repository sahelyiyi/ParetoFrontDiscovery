# %% [markdown]
# Here we have candidate sets for Pareto optimal solutions in objective space of the first numerical result of the paper

# %%
from IPython.display import Image
Image("homotopy/results/paper_result.png")

# %% [markdown]
# The results for our implementation are:

# %%
from homotopy.algorithm import run

run()
# Out:
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/scipy/optimize/_minimize.py:518: RuntimeWarning: Method Nelder-Mead cannot handle constraints nor bounds.
#   RuntimeWarning)
# first x: [0.24997138 0.39813963] , alpha: [0.5 0.5]
# F(x, alpha) should be 0, F: [-0.76253398  0.7622413   0.        ]
# best x for error=1e-1:  [[0.31499778 0.25483507]]
#
# second x: [0.75 0.6 ] , alpha: [0.5 0.5]
# F(x, alpha) should be 0, F: [ 0.75462619 -0.7621668   0.        ]
# best x for error=1e-1:  [[0.67184874 0.75721946]]
#
# third x: [0.5 0.5] , alpha: [0.5 0.5]
# F(x, alpha) should be 0, F: [-1.11022302e-16  1.11022302e-16  0.00000000e+00]
# best x for error=1e-1:  [[-1.11513243  0.0131639 ]]
# best x for error=1e-2:  [[0.4999249  0.49966421]]

# %% [markdown]
# The plot of our iterations results for the candidate set 1 with newton error=1e-1 is:
#
# The red point is the initial point and the blue ones are the points obtained in the iterations.

# %%
Image("homotopy/results/candidate_set_1.jpg", width=450, height=450)

# %% [markdown]
# Also, the plot of the candidate set 2 with newton error=1e-1 is:

# %%
Image("homotopy/results/candidate_set_2.jpg", width=450, height=450)

# %% [markdown]
# It's plot of the candidate set 3 with newton error=1e-1 is:

# %%
Image("homotopy/results/candidate_set_3.jpg", width=450, height=450)

# %% [markdown]
# Also, it's plot of the candidate set 3 with newton error=1e-2 is:

# %%
Image("homotopy/results/candidate_set_3_error.jpg", width=450, height=450)

# %% [markdown]
# As you see, the results of the first 2 sets are identical, but for the 3rd one,  plots are different. At the 3rd set, we don't have any newton iterations to reach the best point, and the initial point already is the efficient point. Also, for this numerical result, the paper has said that "According to Section 2.2, this is a non-generic behavior. "
